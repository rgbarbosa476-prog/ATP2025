# %% [markdown]
# ### TPC3: Aplicação para manipulação de listas de inteiros
# - Crie uma aplicação em Python que coloca no monitor o seguinte menu:
#     * (1) Criar Lista
#     * (2) Ler Lista
#     * (3) Soma
#     * (4) Média
#     * (5) Maior
#     * (6) Menor
#     * (7) estaOrdenada por ordem crescente
#     * (8) estaOrdenada por ordem decrescente
#     * (9) Procura um elemento
#     * (0) Sair
# - O utilizador irá escolher uma das opções introduzindo o número correspondente;
# - Se a opção não for sair, a aplicação executa a operação pretendida, apresenta o resultado e a seguir apresenta de novo o menu;
# - Se a opção for sair, a aplicação termina colocando uma mensagem no monitor.
#
# * No desenvolvimento da aplicação deverá ter em atenção o seguinte:
#     - A aplicação terá uma variável interna para guardar uma lista de números;
#     - Na opção 1, deverá ser criada uma lista de números aleatórios entre 1 e 100 que será guardada na variável interna;
#     - Na opção 2, deverá ser criada uma lista com números introduzidos pelo utilizador, que será guardada na variável interna;
#     - Nestas primeiras opções, se a variável interna já tiver uma lista, esta será sobreposta/apagada pela nova lista;
#     - Na opção 3, será calculada a soma dos elementos na lista no momento;
#     - Na opção 4, será calculada a média dos elementos na lista no momento;
#     - Na opção 5, será calculado o maior elemento da lista no momento;
#     - Na opção 6, será calculado o menor elemento da lista no momento;
#     - Na opção 7, a aplicação deverá indicar (Sim/Não) se a lista está ordenada por ordem crescente;
#     - Na opção 8, a aplicação deverá indicar (Sim/Não) se a lista está ordenada por ordem decrescente;
#     - Na opção 9, a aplicação irá procurar um elemento na lista, se o encontrar deverá devolver a sua posição, devolverá -1 se o elemento não estiver na lista;
#     - Se o utilizador selecionar a opção 0, a aplicação deverá terminar mostrando a lista que está nesse momento guardada.

# %%
#tpc3

Lista = []
import random

def criarLista(N):
    global Lista
    Lista = []
    n = 1
    while n <= N:
        n = n + 1
        Lista.append(random.randint(1,100))
    return Lista

def lerLista(N):
    global Lista
    Lista = []
    k = 0
    while k < N:
        k = k + 1
        Lista.append(int(input("Introduza um número:")))
    return Lista

def somaLista(N):
    soma = 0 
    for n in N:
        soma = soma + n
    return soma

def mediaLista(N):
    soma = 0 
    for n in N:
        soma = soma + n
    return (soma/len(N))

def maiorLista(N):
    maior = N [0]
    for x in N:
        if x > maior:
            maior = x
    return maior

def menorLista(N): 
    menor = N [0]
    for x in N:
        if x < menor:
            menor = x
    return menor 

def estaOrdenadaCres(N):
    for i in range (len(N) - 1):
        if N[i] > N[i+1]:
            return "Não"
    return "Sim" 

def estaOrdenadaDeCres(N):
    global Lista
    for i in range (len(N) - 1):
        if N[i] < N[i+1]:
            return "Não"
    return "Sim" 

def indiceDe (N, elem):
    cond = -1
    if elem in N:
        cond = N.index(elem) + 1
    return cond

escolha = -1
print ("(1) Criar Lista")
print ("(2) Ler Lista")
print ("(3) Soma")
print ("(4) Média")
print ("(5) Maior")
print ("(6) Menor")
print ("(7) estaOrdenada por ordem crescente")
print ("(8) estaOrdenada por ordem decrescente")
print ("(9) Procura um elemento")
print ("(0) Sair")

while escolha != "0":
 
    escolha = (input("Escolhe uma das opções introduzindo o número correspondente:")) 

    if escolha == "1":
        print("Lista criada:", criarLista(int(input("Intoduza o total de números que quer na lista"))))

    elif escolha == "2":  
        print("Lista Lida:", lerLista(int(input("Intoduza o total de números que quer na lista"))))
    
    elif escolha == "3": 
        print("Soma dos elementos da lista:", somaLista(Lista))

    elif escolha == "4": 
        print("Média dos elementos da lista:", mediaLista(Lista))

    elif escolha == "5":          
        print("Maior elemento da lista:", maiorLista(Lista))

    elif escolha == "6":    
        print("Menor elemento da lista:", menorLista(Lista))

    elif escolha == "7":
        resultado = estaOrdenadaCres(Lista)
        print("Ordem Crescente:", resultado)

    elif escolha == "8":
        resultado2 = estaOrdenadaDeCres(Lista)
        print("Ordem Derescente:", resultado2)

    elif escolha == "9":
        print("Lista Atual", Lista)
        num = int(input("Número a procurar:"))
        pro = indiceDe(Lista, num)
        if pro == -1:
            print (-1)
        else:
            print(f"Elemento encontrado na posição {pro}.")
    elif escolha == "0":
            print("Aplicação terminada. Lista final:", Lista)
    else:
            print("Opção inválida. Tenta novamente.")
# Out:
# (1) Criar Lista
# (2) Ler Lista
# (3) Soma
# (4) Média
# (5) Maior
# (6) Menor
# (7) estaOrdenada por ordem crescente
# (8) estaOrdenada por ordem decrescente
# (9) Procura um elemento
# (0) Sair
# Lista criada: [39, 36, 50]
# Soma dos elementos da lista: 125
# Média dos elementos da lista: 41.666666666666664
# Maior elemento da lista: 50
# Menor elemento da lista: 36
# Ordem Crescente: Não
# Ordem Derescente: Não
# Lista Atual [39, 36, 50]
# -1
# Aplicação terminada. Lista final: [39, 36, 50]
